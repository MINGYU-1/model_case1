# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 1. JSON 파일 로드
with open('compare_results_new.json', 'r') as f:
    data = json.load(f)

# 2. 데이터프레임 구조로 변환 (Seaborn 시각화에 최적화)
# 각 리스트의 길이가 같으므로 판다스 데이터프레임으로 바로 변환 가능합니다.
df = pd.DataFrame(data)
stats = df.describe()

# %%
stats
# Out:
#        gamma_0_1  gamma_0_3  gamma_0_5  gamma_0_7  gamma_0_9  gamma_1_1
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.870738   0.869484   0.860401   0.848550   0.840710   0.835009
# std     0.018235   0.009103   0.013019   0.013681   0.015447   0.014530
# min     0.822204   0.849372   0.835285   0.820844   0.804736   0.814116
# 25%     0.860846   0.866417   0.854477   0.839215   0.831413   0.823879
# 50%     0.869317   0.869695   0.862376   0.847540   0.841712   0.831984
# 75%     0.883793   0.875760   0.868571   0.859592   0.852839   0.846966
# max     0.898486   0.883199   0.880673   0.874325   0.863091   0.860566

# %%
print(stats.loc[['mean','std']].astype('float32').round(4))
# 3. 그래프 스타일 설정
plt.figure(figsize=(4, 6))
sns.set_theme(style="whitegrid")

# 4. Boxplot 그리기
# r2_prob, r2_bin, r2_no 세 컬럼을 한 번에 표현
sns.boxplot(data=df, palette="Set3", width=0.5)
# sns.stripplot(data=df, color=".3", size=4, alpha=0.5) # 실제 데이터 포인트 산점도 추가

# 5. 그래프 제목 및 축 라벨 설정
plt.title('CASE1_Final_R2 Metric', fontsize=15)
plt.ylabel('R2 Score', fontsize=12)
# plt.xlabel('Condition Type', fontsize=12)
plt.ylim(0.75, 0.95) # 데이터 범위에 맞춰 Y축 조정
plt.savefig('space_time.png')
# 6. 결과 출력
plt.show()
# Out:
#       R2_With_React
# mean         0.8719
# std          0.0169
