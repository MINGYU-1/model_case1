# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import numpy as np
import torch
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

from model.m26_bin import MultiDecoderCondVAE
from loss.l26oss_all import integrated_loss_fn
from vae_earlystopping import EarlyStopping

def draw_boxplot(scores, title="R2 scores (test)"):
    plt.figure()
    plt.boxplot(scores, vert=True)
    plt.ylabel("R2")
    plt.title(title)
    plt.show()

x_data = np.load('./data/metal.npy')
c_data = np.load('./data/pre_re_fin_expand.npy')
# s_data = np.load('./data/support.npy')  # 현재 코드에서는 안 쓰고 있습니다.

r2_scores = []
seeds = torch.randint(1, 100, (20,))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for n in seeds:
    seed = int(n)

    # split
    x_train, x_test, c_train, c_test = train_test_split(
        x_data, c_data, random_state=seed, test_size=0.4
    )
    x_val, x_test, c_val, c_test = train_test_split(
        x_test, c_test, random_state=seed, test_size=0.5
    )

    # scaling (fit은 train에만)
    x_scaler = MaxAbsScaler()
    c_scaler = StandardScaler()

    x_train = x_scaler.fit_transform(x_train)
    c_train = c_scaler.fit_transform(c_train)

    x_val = x_scaler.transform(x_val)
    x_test = x_scaler.transform(x_test)
    c_val = c_scaler.transform(c_val)
    c_test = c_scaler.transform(c_test)

    # torch tensors
    x_train = torch.tensor(x_train, dtype=torch.float32)
    x_val   = torch.tensor(x_val,   dtype=torch.float32)
    x_test  = torch.tensor(x_test,  dtype=torch.float32)

    c_train = torch.tensor(c_train, dtype=torch.float32)
    c_val   = torch.tensor(c_val,   dtype=torch.float32)
    c_test  = torch.tensor(c_test,  dtype=torch.float32)

    # loaders (train은 보통 shuffle=True 권장)
    train_loader = DataLoader(TensorDataset(x_train, c_train), batch_size=64, shuffle=True)
    val_loader   = DataLoader(TensorDataset(x_val,   c_val),   batch_size=64, shuffle=False)
    test_loader  = DataLoader(TensorDataset(x_test,  c_test),  batch_size=64, shuffle=False)

    # model
    x_dim = x_train.shape[1]
    c_dim = c_train.shape[1]
    model = MultiDecoderCondVAE(x_dim, c_dim, z_dim=8).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    early_stopping = EarlyStopping(patience=40, min_delta=1e-9)

    history = {
        'train_loss': [], 'train_bce': [], 'train_mse': [], 'train_kl': [],
        'val_loss': [],   'val_bce': [],   'val_mse': [],   'val_kl': []
    }

    epochs = 800
    for epoch in range(1, epochs + 1):
        # ---------- train (epoch) ----------
        model.train()
        t_loss = t_mse = t_bce = t_kl = 0.0

        for x, c in train_loader:
            x, c = x.to(device), c.to(device)
            optimizer.zero_grad()

            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x, c)
            loss_dict = integrated_loss_fn(bce_logit, x_hat, x, z_mu, z_logvar)

            loss_dict['loss'].backward()
            optimizer.step()

            t_loss += loss_dict['loss'].item()
            t_mse  += loss_dict['mse_loss'].item()
            t_bce  += loss_dict['bce_loss'].item()
            t_kl   += loss_dict['kl_loss'].item()

        avg_train_loss = t_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)
        history['train_mse'].append(t_mse / len(train_loader))
        history['train_bce'].append(t_bce / len(train_loader))
        history['train_kl'].append(t_kl / len(train_loader))

        # ---------- val (epoch) ----------
        model.eval()
        v_loss = v_mse = v_bce = v_kl = 0.0
        with torch.no_grad():
            for v_x, v_c in val_loader:
                v_x, v_c = v_x.to(device), v_c.to(device)
                v_bce_logit, v_binary_out, v_x_hat, v_mu, v_logvar = model(v_x, v_c)
                loss_dict = integrated_loss_fn(v_bce_logit, v_x_hat, v_x, v_mu, v_logvar)

                v_loss += loss_dict['loss'].item()
                v_mse  += loss_dict['mse_loss'].item()
                v_bce  += loss_dict['bce_loss'].item()
                v_kl   += loss_dict['kl_loss'].item()

        avg_val_loss = v_loss / len(val_loader)
        history['val_loss'].append(avg_val_loss)
        history['val_mse'].append(v_mse / len(val_loader))
        history['val_bce'].append(v_bce / len(val_loader))
        history['val_kl'].append(v_kl / len(val_loader))

        if epoch % 20 == 0 or epoch == 2:
            print(f'Epoch [{epoch}/{epochs}] | Train:{avg_train_loss:.4f} | Val:{avg_val_loss:.4f}')

        # early stopping (epoch 단위)
        if early_stopping(avg_val_loss, model):
            break

    # best model 로드
    early_stopping.load_best_model(model)
    model.eval()

    # ---------- test ----------
    x_true = []
    x_pred = []
    with torch.no_grad():
        for x_t, c_t in test_loader:
            x_t, c_t = x_t.to(device), c_t.to(device)
            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x_t, c_t)

            prob_mask = torch.sigmoid(bce_logit)
            x_hat = x_hat * prob_mask

            x_true.append(x_t.cpu().numpy())
            x_pred.append(x_hat.cpu().numpy())

    all_x_true = np.vstack(x_true)
    all_x_hat  = np.vstack(x_pred)

    # R2: 스케일된 공간에서 계산 (원하면 raw로 바꿀 수 있음)
    r2 = r2_score(all_x_true.flatten(), all_x_hat.flatten())
    r2_scores.append(r2)

# 결과 시각화
draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
print("R2 mean:", float(np.mean(f'{r2_scores:.4f}')))
print("R2 std :", float(np.std(f'{r2_scores:.4f}')))
# Out:
# Epoch [2/800] | Train:3.9065 | Val:3.7030
# Epoch [20/800] | Train:1.4054 | Val:1.3912
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:0.8250 | Val:0.9136
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.6299 | Val:0.7641
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.5132 | Val:0.6745
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [100/800] | Train:0.4319 | Val:0.6377
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.3907 | Val:0.6180
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.3700 | Val:0.6540
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [160/800] | Train:0.3446 | Val:0.6515
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [180/800] | Train:0.3275 | Val:0.6425
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [200/800] | Train:0.3168 | Val:0.6520
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# Epoch [220/800] | Train:0.3257 | Val:0.6067
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [240/800] | Train:0.2926 | Val:0.6445
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# Epoch [260/800] | Train:0.3017 | Val:0.6745
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.568498
# Epoch [2/800] | Train:3.9784 | Val:3.5120
# Epoch [20/800] | Train:1.4844 | Val:1.4913
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.9190 | Val:0.9902
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.6468 | Val:0.7394
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.5206 | Val:0.6807
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [100/800] | Train:0.4303 | Val:0.6194
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.3763 | Val:0.5727
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [140/800] | Train:0.3386 | Val:0.5610
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [160/800] | Train:0.3186 | Val:0.5297
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [180/800] | Train:0.3037 | Val:0.5562
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# Epoch [200/800] | Train:0.3143 | Val:0.5467
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [220/800] | Train:0.2960 | Val:0.5458
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# Epoch [240/800] | Train:0.2797 | Val:0.5625
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.486739
# Epoch [2/800] | Train:3.9164 | Val:3.7430
# Epoch [20/800] | Train:1.2731 | Val:1.3423
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7422 | Val:0.8483
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [60/800] | Train:0.5304 | Val:0.6201
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.4402 | Val:0.5813
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.3930 | Val:0.5421
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.3587 | Val:0.5112
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [140/800] | Train:0.3238 | Val:0.4529
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [160/800] | Train:0.3230 | Val:0.4697
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [180/800] | Train:0.3274 | Val:0.5130
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# Epoch [200/800] | Train:0.2940 | Val:0.4732
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [220/800] | Train:0.2897 | Val:0.4467
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [240/800] | Train:0.2870 | Val:0.4898
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [260/800] | Train:0.2749 | Val:0.4534
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [280/800] | Train:0.2645 | Val:0.4497
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [300/800] | Train:0.2598 | Val:0.4485
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [320/800] | Train:0.2561 | Val:0.4590
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# Epoch [340/800] | Train:0.2555 | Val:0.4579
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.403904
# Epoch [2/800] | Train:3.7848 | Val:3.5275
# Epoch [20/800] | Train:1.2275 | Val:1.3711
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:0.7331 | Val:0.9375
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [60/800] | Train:0.5314 | Val:0.8725
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [80/800] | Train:0.4493 | Val:0.8375
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [100/800] | Train:0.3785 | Val:0.7860
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# Epoch [120/800] | Train:0.3522 | Val:0.7400
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [140/800] | Train:0.3468 | Val:0.7523
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# Epoch [160/800] | Train:0.3223 | Val:0.8313
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.708992
# Epoch [2/800] | Train:3.8593 | Val:3.5686
# Epoch [20/800] | Train:1.4050 | Val:1.4310
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7836 | Val:0.8873
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5842 | Val:0.8159
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.4905 | Val:0.6906
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [100/800] | Train:0.4233 | Val:0.6524
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [120/800] | Train:0.3747 | Val:0.6309
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [140/800] | Train:0.3724 | Val:0.5898
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [160/800] | Train:0.3144 | Val:0.5780
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# Epoch [180/800] | Train:0.2918 | Val:0.5695
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.550085
# Epoch [2/800] | Train:3.9740 | Val:3.6567
# Epoch [20/800] | Train:1.3405 | Val:1.4072
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7826 | Val:0.9008
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5598 | Val:0.7125
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.4488 | Val:0.6080
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [100/800] | Train:0.3882 | Val:0.6080
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.3612 | Val:0.5469
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [140/800] | Train:0.3319 | Val:0.5688
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# Epoch [160/800] | Train:0.3010 | Val:0.5114
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [180/800] | Train:0.3116 | Val:0.5060
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [200/800] | Train:0.2851 | Val:0.5007
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [220/800] | Train:0.2944 | Val:0.5309
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [240/800] | Train:0.2687 | Val:0.4953
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# Epoch [260/800] | Train:0.2755 | Val:0.4869
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.463682
# Epoch [2/800] | Train:3.9214 | Val:3.6889
# Epoch [20/800] | Train:1.3212 | Val:1.3752
# Epoch [40/800] | Train:0.7759 | Val:0.9336
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [60/800] | Train:0.5960 | Val:0.8222
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.4828 | Val:0.6562
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [100/800] | Train:0.4200 | Val:0.6201
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [120/800] | Train:0.3734 | Val:0.5584
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [140/800] | Train:0.3380 | Val:0.5823
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [160/800] | Train:0.3126 | Val:0.5573
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [180/800] | Train:0.2992 | Val:0.5594
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [200/800] | Train:0.2817 | Val:0.5371
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# ...
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.6168 | Val:0.7758
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.4755 | Val:0.6674
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [100/800] | Train:0.3948 | Val:0.5877
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [120/800] | Train:0.3513 | Val:0.5654
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [140/800] | Train:0.3264 | Val:0.5469
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [160/800] | Train:0.3069 | Val:0.4974
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# Epoch [180/800] | Train:0.2957 | Val:0.5245
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.470472
# Epoch [2/800] | Train:3.8770 | Val:3.6497
# Epoch [20/800] | Train:1.3497 | Val:1.4058
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:0.7637 | Val:0.8933
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [60/800] | Train:0.5993 | Val:0.7148
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.4848 | Val:0.6179
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [100/800] | Train:0.3971 | Val:0.5478
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# Epoch [120/800] | Train:0.3675 | Val:0.5065
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.3314 | Val:0.5308
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [160/800] | Train:0.3047 | Val:0.4810
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [180/800] | Train:0.3012 | Val:0.5278
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [200/800] | Train:0.3027 | Val:0.4839
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# Epoch [220/800] | Train:0.2845 | Val:0.4941
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# Epoch [240/800] | Train:0.2717 | Val:0.5350
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.464384
# Epoch [2/800] | Train:3.7436 | Val:3.7371
# Epoch [20/800] | Train:1.3783 | Val:1.6009
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7939 | Val:1.0043
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5774 | Val:0.7978
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.4624 | Val:0.6781
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [100/800] | Train:0.3960 | Val:0.6561
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [120/800] | Train:0.3646 | Val:0.6482
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# Epoch [140/800] | Train:0.3308 | Val:0.6476
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [160/800] | Train:0.3200 | Val:0.6107
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# Epoch [180/800] | Train:0.2930 | Val:0.6075
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.586943
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 161
#     159 # 결과 시각화
#     160 draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
# --> 161 print("R2 mean:", float(np.mean(f'{r2_scores:.4f}')))
#     162 print("R2 std :", float(np.std(f'{r2_scores:.4f}')))
#
# TypeError: unsupported format string passed to list.__format__

# %%
r2_bin = {"r2_bin": r2_scores}

# %%
import json

save_path = "r2_bin.json"

with open(save_path, 'a') as f:
    # float 타입 데이터도 json.dump를 통해 안전하게 저장됩니다.
    json.dump(r2_bin, f, indent=4)

print(f"숫자 형태로 {save_path}에 저장 완료!")
# Out:
# 숫자 형태로 r2_bin.json에 저장 완료!
