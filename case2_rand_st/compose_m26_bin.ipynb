# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import numpy as np
import torch
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

from model.m26_bin import MultiDecoderCondVAE
from loss.l26oss_all import integrated_loss_fn
from vae_earlystopping import EarlyStopping

def draw_boxplot(scores, title="R2 scores (test)"):
    plt.figure()
    plt.boxplot(scores, vert=True)
    plt.ylabel("R2")
    plt.title(title)
    plt.show()

x_data = np.load('./data/metal.npy')
c_data = np.load('./data/pre_re_fin_expand.npy')
# s_data = np.load('./data/support.npy')  # 현재 코드에서는 안 쓰고 있습니다.

r2_scores = []
seeds = torch.randint(1, 100, (20,))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for n in seeds:
    seed = int(n)

    # split
    x_train, x_test, c_train, c_test = train_test_split(
        x_data, c_data, random_state=seed, test_size=0.4
    )
    x_val, x_test, c_val, c_test = train_test_split(
        x_test, c_test, random_state=seed, test_size=0.5
    )

    # scaling (fit은 train에만)
    x_scaler = MaxAbsScaler()
    c_scaler = StandardScaler()

    x_train = x_scaler.fit_transform(x_train)
    c_train = c_scaler.fit_transform(c_train)

    x_val = x_scaler.transform(x_val)
    x_test = x_scaler.transform(x_test)
    c_val = c_scaler.transform(c_val)
    c_test = c_scaler.transform(c_test)

    # torch tensors
    x_train = torch.tensor(x_train, dtype=torch.float32)
    x_val   = torch.tensor(x_val,   dtype=torch.float32)
    x_test  = torch.tensor(x_test,  dtype=torch.float32)

    c_train = torch.tensor(c_train, dtype=torch.float32)
    c_val   = torch.tensor(c_val,   dtype=torch.float32)
    c_test  = torch.tensor(c_test,  dtype=torch.float32)

    # loaders (train은 보통 shuffle=True 권장)
    train_loader = DataLoader(TensorDataset(x_train, c_train), batch_size=64, shuffle=True)
    val_loader   = DataLoader(TensorDataset(x_val,   c_val),   batch_size=64, shuffle=False)
    test_loader  = DataLoader(TensorDataset(x_test,  c_test),  batch_size=64, shuffle=False)

    # model
    x_dim = x_train.shape[1]
    c_dim = c_train.shape[1]
    model = MultiDecoderCondVAE(x_dim, c_dim, z_dim=8).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    early_stopping = EarlyStopping(patience=40, min_delta=1e-9)

    history = {
        'train_loss': [], 'train_bce': [], 'train_mse': [], 'train_kl': [],
        'val_loss': [],   'val_bce': [],   'val_mse': [],   'val_kl': []
    }

    epochs = 800
    for epoch in range(1, epochs + 1):
        # ---------- train (epoch) ----------
        model.train()
        t_loss = t_mse = t_bce = t_kl = 0.0

        for x, c in train_loader:
            x, c = x.to(device), c.to(device)
            optimizer.zero_grad()

            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x, c)
            loss_dict = integrated_loss_fn(bce_logit, x_hat, x, z_mu, z_logvar)

            loss_dict['loss'].backward()
            optimizer.step()

            t_loss += loss_dict['loss'].item()
            t_mse  += loss_dict['mse_loss'].item()
            t_bce  += loss_dict['bce_loss'].item()
            t_kl   += loss_dict['kl_loss'].item()

        avg_train_loss = t_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)
        history['train_mse'].append(t_mse / len(train_loader))
        history['train_bce'].append(t_bce / len(train_loader))
        history['train_kl'].append(t_kl / len(train_loader))

        # ---------- val (epoch) ----------
        model.eval()
        v_loss = v_mse = v_bce = v_kl = 0.0
        with torch.no_grad():
            for v_x, v_c in val_loader:
                v_x, v_c = v_x.to(device), v_c.to(device)
                v_bce_logit, v_binary_out, v_x_hat, v_mu, v_logvar = model(v_x, v_c)
                loss_dict = integrated_loss_fn(v_bce_logit, v_x_hat, v_x, v_mu, v_logvar)

                v_loss += loss_dict['loss'].item()
                v_mse  += loss_dict['mse_loss'].item()
                v_bce  += loss_dict['bce_loss'].item()
                v_kl   += loss_dict['kl_loss'].item()

        avg_val_loss = v_loss / len(val_loader)
        history['val_loss'].append(avg_val_loss)
        history['val_mse'].append(v_mse / len(val_loader))
        history['val_bce'].append(v_bce / len(val_loader))
        history['val_kl'].append(v_kl / len(val_loader))

        if epoch % 20 == 0 or epoch == 2:
            print(f'Epoch [{epoch}/{epochs}] | Train:{avg_train_loss:.4f} | Val:{avg_val_loss:.4f}')

        # early stopping (epoch 단위)
        if early_stopping(avg_val_loss, model):
            break

    # best model 로드
    early_stopping.load_best_model(model)
    model.eval()

    # ---------- test ----------
    x_true = []
    x_pred = []
    with torch.no_grad():
        for x_t, c_t in test_loader:
            x_t, c_t = x_t.to(device), c_t.to(device)
            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x_t, c_t)

            prob_mask = torch.sigmoid(bce_logit)
            x_hat = x_hat * prob_mask

            x_true.append(x_t.cpu().numpy())
            x_pred.append(x_hat.cpu().numpy())

    all_x_true = np.vstack(x_true)
    all_x_hat  = np.vstack(x_pred)

    # R2: 스케일된 공간에서 계산 (원하면 raw로 바꿀 수 있음)
    r2 = r2_score(all_x_true.flatten(), all_x_hat.flatten())
    r2_scores.append(r2)

# 결과 시각화
draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
print("R2 mean:", float(np.mean(f'{r2_scores:.4f}')))
print("R2 std :", float(np.std(f'{r2_scores:.4f}')))
# Out:
# Epoch [2/800] | Train:3.8829 | Val:3.4921
# Epoch [20/800] | Train:2.0293 | Val:2.0043
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.3267 | Val:1.3579
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9632 | Val:1.0512
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8042 | Val:0.9450
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.7043 | Val:0.8935
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [120/800] | Train:0.6521 | Val:0.8629
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.6061 | Val:0.8388
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [160/800] | Train:0.5650 | Val:0.8196
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [180/800] | Train:0.5414 | Val:0.7903
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [200/800] | Train:0.5230 | Val:0.7901
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [220/800] | Train:0.4961 | Val:0.7949
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [240/800] | Train:0.4784 | Val:0.7894
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [260/800] | Train:0.4778 | Val:0.7719
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [280/800] | Train:0.4548 | Val:0.7626
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# Epoch [300/800] | Train:0.4555 | Val:0.7418
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [320/800] | Train:0.4242 | Val:0.7697
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# Epoch [340/800] | Train:0.4217 | Val:0.7779
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.741807
# Epoch [2/800] | Train:3.7762 | Val:3.3881
# Epoch [20/800] | Train:1.9807 | Val:1.9675
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.3585 | Val:1.3682
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:1.0317 | Val:1.0670
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8385 | Val:0.9106
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.7442 | Val:0.8312
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.6528 | Val:0.7937
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.6114 | Val:0.7426
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [160/800] | Train:0.5670 | Val:0.7189
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [180/800] | Train:0.5536 | Val:0.6733
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [200/800] | Train:0.5192 | Val:0.6918
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [220/800] | Train:0.4933 | Val:0.6499
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [240/800] | Train:0.4840 | Val:0.6524
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# Epoch [260/800] | Train:0.4530 | Val:0.6348
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [280/800] | Train:0.4382 | Val:0.6634
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [300/800] | Train:0.4364 | Val:0.6552
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [320/800] | Train:0.4188 | Val:0.6215
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.607091
# Epoch [2/800] | Train:3.8546 | Val:3.4812
# Epoch [20/800] | Train:2.0184 | Val:2.0777
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [40/800] | Train:1.3898 | Val:1.5257
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:1.0181 | Val:1.2531
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.8332 | Val:1.0864
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [100/800] | Train:0.7180 | Val:0.9681
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.6383 | Val:0.9316
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [140/800] | Train:0.6001 | Val:0.8618
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [160/800] | Train:0.5633 | Val:0.8439
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [180/800] | Train:0.5460 | Val:0.8401
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [200/800] | Train:0.5224 | Val:0.8209
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [220/800] | Train:0.5041 | Val:0.8258
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [240/800] | Train:0.4797 | Val:0.8154
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [260/800] | Train:0.4696 | Val:0.8090
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [280/800] | Train:0.4553 | Val:0.7814
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [300/800] | Train:0.4405 | Val:0.7730
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [320/800] | Train:0.4258 | Val:0.7785
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.761756
# Epoch [2/800] | Train:3.8854 | Val:3.5544
# Epoch [20/800] | Train:1.8948 | Val:2.0711
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2723 | Val:1.4826
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9763 | Val:1.2185
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8063 | Val:1.0245
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [100/800] | Train:0.7083 | Val:0.9179
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [120/800] | Train:0.6323 | Val:0.8603
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.5886 | Val:0.8387
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5561 | Val:0.8314
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [180/800] | Train:0.5191 | Val:0.8005
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [200/800] | Train:0.4886 | Val:0.7998
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [220/800] | Train:0.4707 | Val:0.7728
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [240/800] | Train:0.4608 | Val:0.7734
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [260/800] | Train:0.4391 | Val:0.7688
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [280/800] | Train:0.4407 | Val:0.7964
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# Epoch [300/800] | Train:0.4292 | Val:0.7479
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [320/800] | Train:0.4154 | Val:0.7933
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# Epoch [340/800] | Train:0.3968 | Val:0.7560
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# Epoch [360/800] | Train:0.3864 | Val:0.7752
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.740205
# Epoch [2/800] | Train:3.8550 | Val:3.5669
# Epoch [20/800] | Train:1.9356 | Val:2.0411
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.3296 | Val:1.4928
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.9947 | Val:1.1797
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8179 | Val:1.0069
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6977 | Val:0.9129
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.6395 | Val:0.8833
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.5812 | Val:0.8441
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [160/800] | Train:0.5491 | Val:0.8595
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [180/800] | Train:0.5297 | Val:0.8476
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [200/800] | Train:0.4977 | Val:0.8443
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.827962
# Epoch [2/800] | Train:3.7938 | Val:3.4492
# Epoch [20/800] | Train:1.9552 | Val:2.0145
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2160 | Val:1.2902
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [60/800] | Train:0.9414 | Val:1.0191
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7933 | Val:0.9034
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6987 | Val:0.8161
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.6448 | Val:0.7850
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [140/800] | Train:0.5999 | Val:0.7444
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5635 | Val:0.7169
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# Epoch [180/800] | Train:0.5412 | Val:0.6879
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [200/800] | Train:0.4996 | Val:0.6966
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [220/800] | Train:0.4855 | Val:0.6843
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# ...
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [240/800] | Train:0.4755 | Val:0.6122
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [260/800] | Train:0.4729 | Val:0.6362
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# Epoch [280/800] | Train:0.4571 | Val:0.6309
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.605397
# Epoch [2/800] | Train:3.9221 | Val:3.5571
# Epoch [20/800] | Train:1.9629 | Val:2.0277
# Epoch [40/800] | Train:1.2851 | Val:1.4032
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9370 | Val:1.0043
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7660 | Val:0.8688
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6701 | Val:0.8147
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.6077 | Val:0.7709
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [140/800] | Train:0.5677 | Val:0.7396
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5325 | Val:0.7299
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [180/800] | Train:0.5033 | Val:0.7280
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [200/800] | Train:0.4833 | Val:0.7200
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# Epoch [220/800] | Train:0.4665 | Val:0.7242
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.700813
# Epoch [2/800] | Train:3.8706 | Val:3.4566
# EarlyStopping counter: 1 out of 40
# Epoch [20/800] | Train:1.9660 | Val:1.9756
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2776 | Val:1.3733
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9820 | Val:1.0927
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8357 | Val:0.9713
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [100/800] | Train:0.7470 | Val:0.8950
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [120/800] | Train:0.6736 | Val:0.8372
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [140/800] | Train:0.6193 | Val:0.8014
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5940 | Val:0.7775
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [180/800] | Train:0.5508 | Val:0.7616
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [200/800] | Train:0.5321 | Val:0.7467
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [220/800] | Train:0.5129 | Val:0.7204
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [240/800] | Train:0.4970 | Val:0.7344
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [260/800] | Train:0.4813 | Val:0.7143
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [280/800] | Train:0.4796 | Val:0.6991
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [300/800] | Train:0.4473 | Val:0.6992
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [320/800] | Train:0.4487 | Val:0.6801
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.669887
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 161
#     159 # 결과 시각화
#     160 draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
# --> 161 print("R2 mean:", float(np.mean(f'{r2_scores:.4f}')))
#     162 print("R2 std :", float(np.std(f'{r2_scores:.4f}')))
#
# TypeError: unsupported format string passed to list.__format__

# %%
r2_bin = {"r2_bin": r2_scores}

# %%
import json

save_path = "r2_bin.json"

with open(save_path, 'a') as f:
    # float 타입 데이터도 json.dump를 통해 안전하게 저장됩니다.
    json.dump(r2_bin, f, indent=4)

print(f"숫자 형태로 {save_path}에 저장 완료!")
# Out:
# 숫자 형태로 r2_bin.json에 저장 완료!
