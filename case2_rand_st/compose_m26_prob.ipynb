# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import numpy as np
import torch
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

from model.m26_prob import MultiDecoderCondVAE
from loss.l26oss_all import integrated_loss_fn
from vae_earlystopping import EarlyStopping

def draw_boxplot(scores, title="R2 scores (test)"):
    plt.figure()
    plt.boxplot(scores, vert=True)
    plt.ylabel("R2")
    plt.title(title)
    plt.show()

x_data = np.load('./data/metal.npy')
c_data = np.load('./data/pre_re_fin_expand.npy')
# s_data = np.load('./data/support.npy')  # 현재 코드에서는 안 쓰고 있습니다.

r2_scores = []
seeds = torch.randint(1, 100, (20,))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for n in seeds:
    seed = int(n)

    # split
    x_train, x_test, c_train, c_test = train_test_split(
        x_data, c_data, random_state=seed, test_size=0.4
    )
    x_val, x_test, c_val, c_test = train_test_split(
        x_test, c_test, random_state=seed, test_size=0.5
    )

    # scaling (fit은 train에만)
    x_scaler = MaxAbsScaler()
    c_scaler = StandardScaler()

    x_train = x_scaler.fit_transform(x_train)
    c_train = c_scaler.fit_transform(c_train)

    x_val = x_scaler.transform(x_val)
    x_test = x_scaler.transform(x_test)
    c_val = c_scaler.transform(c_val)
    c_test = c_scaler.transform(c_test)

    # torch tensors
    x_train = torch.tensor(x_train, dtype=torch.float32)
    x_val   = torch.tensor(x_val,   dtype=torch.float32)
    x_test  = torch.tensor(x_test,  dtype=torch.float32)

    c_train = torch.tensor(c_train, dtype=torch.float32)
    c_val   = torch.tensor(c_val,   dtype=torch.float32)
    c_test  = torch.tensor(c_test,  dtype=torch.float32)

    # loaders (train은 보통 shuffle=True 권장)
    train_loader = DataLoader(TensorDataset(x_train, c_train), batch_size=64, shuffle=True)
    val_loader   = DataLoader(TensorDataset(x_val,   c_val),   batch_size=64, shuffle=False)
    test_loader  = DataLoader(TensorDataset(x_test,  c_test),  batch_size=64, shuffle=False)

    # model
    x_dim = x_train.shape[1]
    c_dim = c_train.shape[1]
    model = MultiDecoderCondVAE(x_dim, c_dim, z_dim=8).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    early_stopping = EarlyStopping(patience=40, min_delta=1e-9)

    history = {
        'train_loss': [], 'train_bce': [], 'train_mse': [], 'train_kl': [],
        'val_loss': [],   'val_bce': [],   'val_mse': [],   'val_kl': []
    }

    epochs = 800
    for epoch in range(1, epochs + 1):
        # ---------- train (epoch) ----------
        model.train()
        t_loss = t_mse = t_bce = t_kl = 0.0

        for x, c in train_loader:
            x, c = x.to(device), c.to(device)
            optimizer.zero_grad()

            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x, c)
            loss_dict = integrated_loss_fn(bce_logit, x_hat, x, z_mu, z_logvar)

            loss_dict['loss'].backward()
            optimizer.step()

            t_loss += loss_dict['loss'].item()
            t_mse  += loss_dict['mse_loss'].item()
            t_bce  += loss_dict['bce_loss'].item()
            t_kl   += loss_dict['kl_loss'].item()

        avg_train_loss = t_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)
        history['train_mse'].append(t_mse / len(train_loader))
        history['train_bce'].append(t_bce / len(train_loader))
        history['train_kl'].append(t_kl / len(train_loader))

        # ---------- val (epoch) ----------
        model.eval()
        v_loss = v_mse = v_bce = v_kl = 0.0
        with torch.no_grad():
            for v_x, v_c in val_loader:
                v_x, v_c = v_x.to(device), v_c.to(device)
                v_bce_logit, v_binary_out, v_x_hat, v_mu, v_logvar = model(v_x, v_c)
                loss_dict = integrated_loss_fn(v_bce_logit, v_x_hat, v_x, v_mu, v_logvar)

                v_loss += loss_dict['loss'].item()
                v_mse  += loss_dict['mse_loss'].item()
                v_bce  += loss_dict['bce_loss'].item()
                v_kl   += loss_dict['kl_loss'].item()

        avg_val_loss = v_loss / len(val_loader)
        history['val_loss'].append(avg_val_loss)
        history['val_mse'].append(v_mse / len(val_loader))
        history['val_bce'].append(v_bce / len(val_loader))
        history['val_kl'].append(v_kl / len(val_loader))

        if epoch % 20 == 0 or epoch == 2:
            print(f'Epoch [{epoch}/{epochs}] | Train:{avg_train_loss:.4f} | Val:{avg_val_loss:.4f}')

        # early stopping (epoch 단위)
        if early_stopping(avg_val_loss, model):
            break

    # best model 로드
    early_stopping.load_best_model(model)
    model.eval()

    # ---------- test ----------
    x_true = []
    x_pred = []
    with torch.no_grad():
        for x_t, c_t in test_loader:
            x_t, c_t = x_t.to(device), c_t.to(device)
            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x_t, c_t)


            x_true.append(x_t.cpu().numpy())
            x_pred.append(x_hat.cpu().numpy())

    all_x_true = np.vstack(x_true)
    all_x_hat  = np.vstack(x_pred)

    # R2: 스케일된 공간에서 계산 (원하면 raw로 바꿀 수 있음)
    r2 = r2_score(all_x_true.flatten(), all_x_hat.flatten())
    r2_scores.append(r2)

# 결과 시각화
draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
print("R2 mean:", float(np.mean(r2_scores)))
print("R2 std :", float(np.std(r2_scores)))
# Out:
# Epoch [2/800] | Train:3.7575 | Val:3.4388
# Epoch [20/800] | Train:1.9636 | Val:2.0155
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2188 | Val:1.3375
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9328 | Val:1.1088
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7796 | Val:1.0127
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [100/800] | Train:0.6756 | Val:0.9779
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [120/800] | Train:0.6071 | Val:0.9239
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [140/800] | Train:0.5558 | Val:0.9494
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [160/800] | Train:0.5306 | Val:0.8989
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [180/800] | Train:0.5011 | Val:0.9145
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [200/800] | Train:0.4895 | Val:0.8967
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [220/800] | Train:0.4571 | Val:0.8864
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [240/800] | Train:0.4356 | Val:0.9042
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [260/800] | Train:0.4302 | Val:0.8874
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.865587
# Epoch [2/800] | Train:3.9130 | Val:3.3974
# Epoch [20/800] | Train:2.0128 | Val:1.8177
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.3289 | Val:1.2347
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:1.0019 | Val:0.9543
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8499 | Val:0.8462
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.7408 | Val:0.7858
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.6764 | Val:0.7540
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [140/800] | Train:0.6059 | Val:0.7117
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [160/800] | Train:0.5732 | Val:0.7225
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [180/800] | Train:0.5521 | Val:0.7229
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.698940
# Epoch [2/800] | Train:3.7285 | Val:3.3681
# Epoch [20/800] | Train:1.9688 | Val:2.0079
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2894 | Val:1.4538
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:1.0116 | Val:1.1921
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.8081 | Val:1.0050
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6964 | Val:0.9211
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [120/800] | Train:0.6204 | Val:0.8657
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [140/800] | Train:0.5695 | Val:0.8298
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# Epoch [160/800] | Train:0.5380 | Val:0.7976
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [180/800] | Train:0.5110 | Val:0.7982
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [200/800] | Train:0.4702 | Val:0.7796
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# Epoch [220/800] | Train:0.4777 | Val:0.7602
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [240/800] | Train:0.4430 | Val:0.7682
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [260/800] | Train:0.4261 | Val:0.7773
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [280/800] | Train:0.4048 | Val:0.7645
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [300/800] | Train:0.4072 | Val:0.7656
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.746759
# Epoch [2/800] | Train:3.8306 | Val:3.5571
# Epoch [20/800] | Train:1.8783 | Val:2.1175
# Epoch [40/800] | Train:1.2644 | Val:1.4841
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.9528 | Val:1.1949
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.7841 | Val:1.0633
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [100/800] | Train:0.7049 | Val:0.9942
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [120/800] | Train:0.6276 | Val:0.9530
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [140/800] | Train:0.5710 | Val:0.9233
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5327 | Val:0.9337
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [180/800] | Train:0.5008 | Val:0.9180
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [200/800] | Train:0.4819 | Val:0.9051
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [220/800] | Train:0.4571 | Val:0.9113
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# Epoch [240/800] | Train:0.4453 | Val:0.9261
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.885137
# Epoch [2/800] | Train:4.0160 | Val:3.5167
# EarlyStopping counter: 1 out of 40
# Epoch [20/800] | Train:1.8122 | Val:1.9464
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.1547 | Val:1.3593
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [60/800] | Train:0.8891 | Val:1.1184
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7430 | Val:0.9912
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [100/800] | Train:0.6582 | Val:0.9210
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [120/800] | Train:0.6142 | Val:0.9056
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.5707 | Val:0.8766
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [160/800] | Train:0.5292 | Val:0.8734
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# Epoch [180/800] | Train:0.5058 | Val:0.8654
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [200/800] | Train:0.4823 | Val:0.8563
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# Epoch [220/800] | Train:0.4753 | Val:0.8392
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.829243
# Epoch [2/800] | Train:3.9895 | Val:3.5068
# Epoch [20/800] | Train:1.8354 | Val:1.7917
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.1957 | Val:1.2501
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.9433 | Val:1.0543
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7816 | Val:0.9344
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [100/800] | Train:0.6878 | Val:0.8644
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [120/800] | Train:0.6327 | Val:0.7930
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.5867 | Val:0.7681
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# Epoch [160/800] | Train:0.5519 | Val:0.8065
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [180/800] | Train:0.5246 | Val:0.7627
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [200/800] | Train:0.5035 | Val:0.7733
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [220/800] | Train:0.4866 | Val:0.7495
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [240/800] | Train:0.4682 | Val:0.7548
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [260/800] | Train:0.4521 | Val:0.7362
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [280/800] | Train:0.4421 | Val:0.7512
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [300/800] | Train:0.4384 | Val:0.7359
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.718297
# Epoch [2/800] | Train:3.9318 | Val:3.3150
# Epoch [20/800] | Train:1.9652 | Val:1.8854
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:1.2912 | Val:1.3172
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9673 | Val:1.0861
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.7969 | Val:0.9793
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [100/800] | Train:0.6945 | Val:0.9102
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [120/800] | Train:0.6474 | Val:0.8745
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.5999 | Val:0.8281
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.5573 | Val:0.8467
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [180/800] | Train:0.5327 | Val:0.8335
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [200/800] | Train:0.5067 | Val:0.8144
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [220/800] | Train:0.4982 | Val:0.8056
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [240/800] | Train:0.4742 | Val:0.8126
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# Epoch [260/800] | Train:0.4558 | Val:0.8020
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.756393
# Epoch [2/800] | Train:4.1524 | Val:3.5381
# Epoch [20/800] | Train:1.9483 | Val:1.8834
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2519 | Val:1.2071
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9531 | Val:0.9525
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [80/800] | Train:0.8022 | Val:0.8155
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [100/800] | Train:0.6982 | Val:0.7646
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# ...
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6211 | Val:0.9379
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.5666 | Val:0.9551
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [140/800] | Train:0.5317 | Val:0.9132
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [160/800] | Train:0.4941 | Val:0.9044
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [180/800] | Train:0.4685 | Val:0.9034
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [200/800] | Train:0.4540 | Val:0.9148
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.890148
# Epoch [2/800] | Train:3.8569 | Val:3.3511
# EarlyStopping counter: 1 out of 40
# Epoch [20/800] | Train:1.9462 | Val:1.8172
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:1.2341 | Val:1.2367
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.9247 | Val:1.0152
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.7796 | Val:0.8843
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.6889 | Val:0.8314
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [120/800] | Train:0.6425 | Val:0.7567
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [140/800] | Train:0.5831 | Val:0.7284
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [160/800] | Train:0.5523 | Val:0.7248
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [180/800] | Train:0.5299 | Val:0.7080
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [200/800] | Train:0.5171 | Val:0.6910
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [220/800] | Train:0.4836 | Val:0.6774
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [240/800] | Train:0.4673 | Val:0.6622
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [260/800] | Train:0.4566 | Val:0.6666
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# Epoch [280/800] | Train:0.4421 | Val:0.6834
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# Epoch [300/800] | Train:0.4364 | Val:0.6534
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# Epoch [320/800] | Train:0.4240 | Val:0.6796
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [340/800] | Train:0.4116 | Val:0.6662
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [360/800] | Train:0.4041 | Val:0.6440
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [380/800] | Train:0.3968 | Val:0.6674
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# Epoch [400/800] | Train:0.3825 | Val:0.6335
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.618731
# R2 mean: 0.7185001164674759
# R2 std : 0.07311255289820977

# %%
r2_prob = {"r2_prob":r2_scores}

# %%
import json

save_path = "r2_prob.json"

with open(save_path, 'w') as f:
    # float 타입 데이터도 json.dump를 통해 안전하게 저장됩니다.
    json.dump(r2_prob, f, indent=4)

print(f"숫자 형태로 {save_path}에 저장 완료!")
# Out:
# 숫자 형태로 r2_prob.json에 저장 완료!
