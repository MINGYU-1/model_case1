# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import numpy as np
import torch
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

from model.m26_prob import MultiDecoderCondVAE
from loss.l26oss_all import integrated_loss_fn
from vae_earlystopping import EarlyStopping

def draw_boxplot(scores, title="R2 scores (test)"):
    plt.figure()
    plt.boxplot(scores, vert=True)
    plt.ylabel("R2")
    plt.title(title)
    plt.show()

x_data = np.load('./data/metal.npy')
c_data = np.load('./data/pre_re_fin_expand.npy')
# s_data = np.load('./data/support.npy')  # 현재 코드에서는 안 쓰고 있습니다.

r2_scores = []
seeds = torch.randint(1, 100, (20,))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for n in seeds:
    seed = int(n)

    # split
    x_train, x_test, c_train, c_test = train_test_split(
        x_data, c_data, random_state=seed, test_size=0.4
    )
    x_val, x_test, c_val, c_test = train_test_split(
        x_test, c_test, random_state=seed, test_size=0.5
    )

    # scaling (fit은 train에만)
    x_scaler = MaxAbsScaler()
    c_scaler = StandardScaler()

    x_train = x_scaler.fit_transform(x_train)
    c_train = c_scaler.fit_transform(c_train)

    x_val = x_scaler.transform(x_val)
    x_test = x_scaler.transform(x_test)
    c_val = c_scaler.transform(c_val)
    c_test = c_scaler.transform(c_test)

    # torch tensors
    x_train = torch.tensor(x_train, dtype=torch.float32)
    x_val   = torch.tensor(x_val,   dtype=torch.float32)
    x_test  = torch.tensor(x_test,  dtype=torch.float32)

    c_train = torch.tensor(c_train, dtype=torch.float32)
    c_val   = torch.tensor(c_val,   dtype=torch.float32)
    c_test  = torch.tensor(c_test,  dtype=torch.float32)

    # loaders (train은 보통 shuffle=True 권장)
    train_loader = DataLoader(TensorDataset(x_train, c_train), batch_size=64, shuffle=True)
    val_loader   = DataLoader(TensorDataset(x_val,   c_val),   batch_size=64, shuffle=False)
    test_loader  = DataLoader(TensorDataset(x_test,  c_test),  batch_size=64, shuffle=False)

    # model
    x_dim = x_train.shape[1]
    c_dim = c_train.shape[1]
    model = MultiDecoderCondVAE(x_dim, c_dim, z_dim=8).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    early_stopping = EarlyStopping(patience=40, min_delta=1e-9)

    history = {
        'train_loss': [], 'train_bce': [], 'train_mse': [], 'train_kl': [],
        'val_loss': [],   'val_bce': [],   'val_mse': [],   'val_kl': []
    }

    epochs = 800
    for epoch in range(1, epochs + 1):
        # ---------- train (epoch) ----------
        model.train()
        t_loss = t_mse = t_bce = t_kl = 0.0

        for x, c in train_loader:
            x, c = x.to(device), c.to(device)
            optimizer.zero_grad()

            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x, c)
            loss_dict = integrated_loss_fn(bce_logit, x_hat, x, z_mu, z_logvar)

            loss_dict['loss'].backward()
            optimizer.step()

            t_loss += loss_dict['loss'].item()
            t_mse  += loss_dict['mse_loss'].item()
            t_bce  += loss_dict['bce_loss'].item()
            t_kl   += loss_dict['kl_loss'].item()

        avg_train_loss = t_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)
        history['train_mse'].append(t_mse / len(train_loader))
        history['train_bce'].append(t_bce / len(train_loader))
        history['train_kl'].append(t_kl / len(train_loader))

        # ---------- val (epoch) ----------
        model.eval()
        v_loss = v_mse = v_bce = v_kl = 0.0
        with torch.no_grad():
            for v_x, v_c in val_loader:
                v_x, v_c = v_x.to(device), v_c.to(device)
                v_bce_logit, v_binary_out, v_x_hat, v_mu, v_logvar = model(v_x, v_c)
                loss_dict = integrated_loss_fn(v_bce_logit, v_x_hat, v_x, v_mu, v_logvar)

                v_loss += loss_dict['loss'].item()
                v_mse  += loss_dict['mse_loss'].item()
                v_bce  += loss_dict['bce_loss'].item()
                v_kl   += loss_dict['kl_loss'].item()

        avg_val_loss = v_loss / len(val_loader)
        history['val_loss'].append(avg_val_loss)
        history['val_mse'].append(v_mse / len(val_loader))
        history['val_bce'].append(v_bce / len(val_loader))
        history['val_kl'].append(v_kl / len(val_loader))

        if epoch % 20 == 0 or epoch == 2:
            print(f'Epoch [{epoch}/{epochs}] | Train:{avg_train_loss:.4f} | Val:{avg_val_loss:.4f}')

        # early stopping (epoch 단위)
        if early_stopping(avg_val_loss, model):
            break

    # best model 로드
    early_stopping.load_best_model(model)
    model.eval()

    # ---------- test ----------
    x_true = []
    x_pred = []
    with torch.no_grad():
        for x_t, c_t in test_loader:
            x_t, c_t = x_t.to(device), c_t.to(device)
            bce_logit, binary_out, x_hat, z_mu, z_logvar = model(x_t, c_t)


            x_true.append(x_t.cpu().numpy())
            x_pred.append(x_hat.cpu().numpy())

    all_x_true = np.vstack(x_true)
    all_x_hat  = np.vstack(x_pred)

    # R2: 스케일된 공간에서 계산 (원하면 raw로 바꿀 수 있음)
    r2 = r2_score(all_x_true.flatten(), all_x_hat.flatten())
    r2_scores.append(r2)

# 결과 시각화
draw_boxplot(r2_scores, title="Test R2 over 20 random splits")
print("R2 mean:", float(np.mean(r2_scores)))
print("R2 std :", float(np.std(r2_scores)))
# Out:
# Epoch [2/800] | Train:3.9148 | Val:3.5272
# Epoch [20/800] | Train:1.3571 | Val:1.3585
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:0.7800 | Val:0.7714
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [60/800] | Train:0.5735 | Val:0.5898
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.4668 | Val:0.4998
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.3756 | Val:0.4403
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.3481 | Val:0.4342
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [140/800] | Train:0.3239 | Val:0.3772
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# Epoch [160/800] | Train:0.2982 | Val:0.3864
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [180/800] | Train:0.2901 | Val:0.3603
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [200/800] | Train:0.2812 | Val:0.3174
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [220/800] | Train:0.2796 | Val:0.3661
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# Epoch [240/800] | Train:0.2604 | Val:0.3716
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.317389
# Epoch [2/800] | Train:3.9043 | Val:3.6007
# Epoch [20/800] | Train:1.3798 | Val:1.4244
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [40/800] | Train:0.7846 | Val:0.8921
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [60/800] | Train:0.5575 | Val:0.7412
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.4834 | Val:0.6612
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [100/800] | Train:0.4277 | Val:0.6192
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [120/800] | Train:0.3818 | Val:0.5679
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.3532 | Val:0.5864
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [160/800] | Train:0.3283 | Val:0.5699
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [180/800] | Train:0.3065 | Val:0.5358
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# Epoch [200/800] | Train:0.2963 | Val:0.5360
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# Epoch [220/800] | Train:0.2833 | Val:0.5056
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [240/800] | Train:0.2830 | Val:0.5424
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [260/800] | Train:0.2744 | Val:0.5197
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# Epoch [280/800] | Train:0.2517 | Val:0.4943
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [300/800] | Train:0.2601 | Val:0.5107
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [320/800] | Train:0.2544 | Val:0.4724
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [340/800] | Train:0.2504 | Val:0.4642
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [360/800] | Train:0.2382 | Val:0.4707
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [380/800] | Train:0.2351 | Val:0.4347
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [400/800] | Train:0.2363 | Val:0.4613
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [420/800] | Train:0.2291 | Val:0.4251
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# Epoch [440/800] | Train:0.2226 | Val:0.4698
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.395571
# Epoch [2/800] | Train:3.9245 | Val:3.5893
# Epoch [20/800] | Train:1.3993 | Val:1.5570
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7826 | Val:0.8693
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [60/800] | Train:0.5555 | Val:0.6718
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.4439 | Val:0.5624
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [100/800] | Train:0.3888 | Val:0.5334
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [120/800] | Train:0.3545 | Val:0.5166
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [140/800] | Train:0.3222 | Val:0.4781
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# Epoch [160/800] | Train:0.3109 | Val:0.4957
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [180/800] | Train:0.2863 | Val:0.4476
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [200/800] | Train:0.2701 | Val:0.4751
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [220/800] | Train:0.2764 | Val:0.4752
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# Epoch [240/800] | Train:0.2583 | Val:0.4661
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# Epoch [260/800] | Train:0.2563 | Val:0.4647
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [280/800] | Train:0.2406 | Val:0.4390
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [300/800] | Train:0.2462 | Val:0.4517
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# Epoch [320/800] | Train:0.2348 | Val:0.4614
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# Epoch [340/800] | Train:0.2374 | Val:0.4690
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.422770
# Epoch [2/800] | Train:3.9774 | Val:3.4251
# Epoch [20/800] | Train:1.3784 | Val:1.4062
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7562 | Val:0.8564
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5605 | Val:0.7580
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [80/800] | Train:0.4617 | Val:0.6697
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [100/800] | Train:0.3765 | Val:0.6521
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# Epoch [120/800] | Train:0.3511 | Val:0.6469
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [140/800] | Train:0.3248 | Val:0.6602
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [160/800] | Train:0.3158 | Val:0.6425
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.602338
# Epoch [2/800] | Train:3.9134 | Val:3.5085
# Epoch [20/800] | Train:1.3701 | Val:1.4617
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.8093 | Val:0.9139
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5768 | Val:0.7130
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.4608 | Val:0.6153
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [100/800] | Train:0.3846 | Val:0.5207
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [120/800] | Train:0.3330 | Val:0.5344
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [140/800] | Train:0.3229 | Val:0.5159
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# Epoch [160/800] | Train:0.2840 | Val:0.5234
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# Epoch [180/800] | Train:0.2783 | Val:0.4882
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# Epoch [200/800] | Train:0.2838 | Val:0.4864
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# Epoch [220/800] | Train:0.2647 | Val:0.4895
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.434303
# Epoch [2/800] | Train:3.7957 | Val:3.5673
# Epoch [20/800] | Train:1.3634 | Val:1.4338
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7859 | Val:0.9109
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [60/800] | Train:0.6007 | Val:0.7390
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.4823 | Val:0.7051
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [100/800] | Train:0.4012 | Val:0.6756
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# Epoch [120/800] | Train:0.3539 | Val:0.5865
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [140/800] | Train:0.3295 | Val:0.5994
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# Epoch [160/800] | Train:0.2915 | Val:0.6195
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# Epoch [180/800] | Train:0.2867 | Val:0.5944
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# Epoch [200/800] | Train:0.2623 | Val:0.5903
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.565735
# Epoch [2/800] | Train:3.9212 | Val:3.6671
# Epoch [20/800] | Train:1.3286 | Val:1.3276
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.8042 | Val:0.8860
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# ...
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [180/800] | Train:0.2862 | Val:0.5150
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# Epoch [200/800] | Train:0.2727 | Val:0.5313
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.467484
# Epoch [2/800] | Train:3.8418 | Val:3.7485
# Epoch [20/800] | Train:1.4265 | Val:1.6505
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.8229 | Val:1.0382
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5958 | Val:0.8420
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# Epoch [80/800] | Train:0.5009 | Val:0.7767
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [100/800] | Train:0.3921 | Val:0.6980
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [120/800] | Train:0.3649 | Val:0.6770
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [140/800] | Train:0.3223 | Val:0.6275
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [160/800] | Train:0.3086 | Val:0.6155
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# Epoch [180/800] | Train:0.3259 | Val:0.6171
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# Epoch [200/800] | Train:0.2830 | Val:0.6119
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.552622
# Epoch [2/800] | Train:3.9673 | Val:3.6661
# Epoch [20/800] | Train:1.2773 | Val:1.4254
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7196 | Val:0.9744
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [60/800] | Train:0.5028 | Val:0.7692
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.4102 | Val:0.7186
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [100/800] | Train:0.3512 | Val:0.6827
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# Epoch [120/800] | Train:0.3210 | Val:0.6554
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# Epoch [140/800] | Train:0.3054 | Val:0.7453
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.650367
# Epoch [2/800] | Train:3.8552 | Val:3.6331
# Epoch [20/800] | Train:1.4232 | Val:1.4773
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [40/800] | Train:0.7959 | Val:0.9112
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# Epoch [60/800] | Train:0.5788 | Val:0.7498
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# Epoch [80/800] | Train:0.4793 | Val:0.6663
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# Epoch [100/800] | Train:0.4313 | Val:0.6313
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 1 out of 40
# Epoch [120/800] | Train:0.3692 | Val:0.5804
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# Epoch [140/800] | Train:0.3220 | Val:0.5699
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# Epoch [160/800] | Train:0.3039 | Val:0.5714
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# Epoch [180/800] | Train:0.2806 | Val:0.5276
# EarlyStopping counter: 1 out of 40
# EarlyStopping counter: 2 out of 40
# EarlyStopping counter: 3 out of 40
# EarlyStopping counter: 4 out of 40
# EarlyStopping counter: 5 out of 40
# EarlyStopping counter: 6 out of 40
# EarlyStopping counter: 7 out of 40
# EarlyStopping counter: 8 out of 40
# EarlyStopping counter: 9 out of 40
# EarlyStopping counter: 10 out of 40
# EarlyStopping counter: 11 out of 40
# EarlyStopping counter: 12 out of 40
# EarlyStopping counter: 13 out of 40
# EarlyStopping counter: 14 out of 40
# EarlyStopping counter: 15 out of 40
# EarlyStopping counter: 16 out of 40
# EarlyStopping counter: 17 out of 40
# EarlyStopping counter: 18 out of 40
# EarlyStopping counter: 19 out of 40
# Epoch [200/800] | Train:0.2921 | Val:0.5567
# EarlyStopping counter: 20 out of 40
# EarlyStopping counter: 21 out of 40
# EarlyStopping counter: 22 out of 40
# EarlyStopping counter: 23 out of 40
# EarlyStopping counter: 24 out of 40
# EarlyStopping counter: 25 out of 40
# EarlyStopping counter: 26 out of 40
# EarlyStopping counter: 27 out of 40
# EarlyStopping counter: 28 out of 40
# EarlyStopping counter: 29 out of 40
# EarlyStopping counter: 30 out of 40
# EarlyStopping counter: 31 out of 40
# EarlyStopping counter: 32 out of 40
# EarlyStopping counter: 33 out of 40
# EarlyStopping counter: 34 out of 40
# EarlyStopping counter: 35 out of 40
# EarlyStopping counter: 36 out of 40
# EarlyStopping counter: 37 out of 40
# EarlyStopping counter: 38 out of 40
# EarlyStopping counter: 39 out of 40
# Epoch [220/800] | Train:0.2731 | Val:0.5609
# EarlyStopping counter: 40 out of 40
# Restored best model with loss: 0.527643
# R2 mean: 0.8498408854007721
# R2 std : 0.08401989753743741

# %%
r2_prob = {"r2_prob":r2_scores}

# %%
import json

save_path = "r2_prob.json"

with open(save_path, 'w') as f:
    # float 타입 데이터도 json.dump를 통해 안전하게 저장됩니다.
    json.dump(r2_prob, f, indent=4)

print(f"숫자 형태로 {save_path}에 저장 완료!")
# Out:
# 숫자 형태로 r2_prob.json에 저장 완료!
