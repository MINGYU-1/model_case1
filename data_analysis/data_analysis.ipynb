# %%
import os
os.getcwd()
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import pandas as pd
df = pd.read_csv("211210-DRM-total.csv")

# %%
df[df.loc[:,'Ni']>0].shape
# Out:
# (4408, 86)

# %%
df[(df.loc[:,'Reaction T']>=700) & (df.loc[:,'Reaction T']<=900)].shape
# Out:
# (4209, 85)

# %%
df['CO2/CH4'] = df.loc[:,'Reaction CO2']/ df.loc[:,'Reaction CH4']

# %%
df[df['CO2/CH4']==1].shape
# Out:
# (5339, 86)
