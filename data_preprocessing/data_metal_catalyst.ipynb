# %%
import pandas as pd
df = pd.read_csv("211210-DRM-total.csv")
metal_df = df.iloc[:,2:25] #금속
support_df = df.iloc[:,25:70] # 지지체

# %% [markdown]
# ## kl_divergence 계수 0.1
# #### domain knowledege에서 반응속도 1로 가정하기
# #### noise eps관련해서 비싼모델, 생성형모델이니깐 추려서 사용

# %%
metal_df.columns
# Out:
# Index(['Co', 'Ba', 'Ca', 'Cu', 'Ce', 'Mn', 'La', 'Ni', 'Ag', 'Pt', 'Mg', 'Ir',
#        'Au', 'K', 'Li', 'Ru', 'Rh', 'Fe', 'Pr', 'Pd', 'Sr', 'Y', 'Zr'],
#       dtype='object')

# %%
support_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 support_df.columns
#
# NameError: name 'support_df' is not defined
