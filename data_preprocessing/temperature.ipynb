# %%
import os
par_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
os.chdir(par_dir)

# %%
import pandas as pd
df =pd.read_csv('211210-DRM-total.csv')

# %%
pre_df = df.iloc[:,71:76]

# %%
react_df= df.iloc[:,76:]

# %%
react_df
# Out:
#       Reaction T  Reaction CH4  Reaction CO2  Reaction Ar  Reaction N2  \
# 0            600          50.0          50.0          0.0          0.0
# 1            600          50.0          50.0          0.0          0.0
# 2            600          50.0          50.0          0.0          0.0
# 3            600          50.0          50.0          0.0          0.0
# 4            600          50.0          50.0          0.0          0.0
# ...          ...           ...           ...          ...          ...
# 5903         700          25.0          25.0          0.0         50.0
# 5904         750          25.0          25.0          0.0         50.0
# 5905         800          25.0          25.0          0.0         50.0
# 5906         850          25.0          25.0          0.0         50.0
# 5907         900          25.0          25.0          0.0         50.0
#
#       Reaction He  GHSV  Time on stream  CH4 Conversion
# 0             0.0   4.0              60              21
# 1             0.0   4.0              60              39
# 2             0.0   4.0              60              45
# 3             0.0   4.0              60              48
# 4             0.0   4.0              60              44
# ...           ...   ...             ...             ...
# 5903          0.0   0.5             120              81
# 5904          0.0   0.5             120              90
# 5905          0.0   0.5             120              95
# 5906          0.0   0.5             120              97
# 5907          0.0   0.5             120              98
#
# [5908 rows x 9 columns]

# %%
react_df['CO2/CH4'] = df.loc[:,'Reaction CO2']/ df.loc[:,'Reaction CH4']

# %%
react_df['CH4 GHSV'] = react_df.loc[:,'Reaction CH4']*react_df.loc[:,'GHSV']/100
react_df['CO2 GHSV'] = react_df.loc[:,'Reaction CO2']*react_df.loc[:,'GHSV']/100
react_df['Space Time'] = 1/react_df.loc[:,'GHSV']

# %%
import numpy as np

X = react_df['CH4 Conversion'] / 100.0                 
yCH4 = react_df['Reaction CH4'] / 100.0
eps = 2.0 * yCH4

react_df['Reaction_Constant'] = ( -eps*X - (1.0 + eps)*np.log(1.0 - X) ) * react_df['GHSV']

# %%
react_df = react_df.loc[:,['Reaction T','CO2/CH4','CH4 GHSV','CO2 GHSV','GHSV','Time on stream','CH4 Conversion','Reaction_Constant']]

# %%
react_df.head()
# Out:
#    Reaction T  CO2/CH4  CH4 GHSV  CO2 GHSV  GHSV  Time on stream  \
# 0         600      1.0       2.0       2.0   4.0              60
# 1         600      1.0       2.0       2.0   4.0              60
# 2         600      1.0       2.0       2.0   4.0              60
# 3         600      1.0       2.0       2.0   4.0              60
# 4         600      1.0       2.0       2.0   4.0              60
#
#    CH4 Conversion  Reaction_Constant
# 0              21           1.045779
# 1              39           2.394371
# 2              45           2.982696
# 3              48           3.311412
# 4              44           2.878548

# %%
import matplotlib.pyplot as plt
data = react_df['CO2/CH4']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    react_df['CO2/CH4'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('CO2/CH4 ratio')
plt.ylabel('Count')
plt.title('Histogram of CO2/CH4 before Processing')

plt.tight_layout()
plt.show()
# Out:
# 1.0119,0.2509

# %%
import numpy as np
react_df['CO2/CH4']= np.log(react_df['CO2/CH4'])

# %%
import matplotlib.pyplot as plt
data = react_df['CO2/CH4']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    react_df['CO2/CH4'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(CO2/CH4 ratio)')
plt.ylabel('Count')
plt.title('Histogram of CO2/CH4 after Processing')

plt.tight_layout()
plt.show()
# Out:
# -0.0077,0.1886

# %%
import matplotlib.pyplot as plt
data = react_df['GHSV']
mean_val = np.mean(data)
std_val = np.std(data)
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('GHSV')
plt.ylabel('Count')
plt.ylim(0,2500)
plt.xlim(0,100)
plt.title('Histogram of GHSV before Processing')

plt.tight_layout()
plt.show()
print(f"{mean_val:.4f},{std_val:.4f}")
# Out:
# 5.9284,9.2057

# %%
react_df['GHSV'] = np.log1p(react_df['GHSV'])

# %%
import matplotlib.pyplot as plt
data = react_df['GHSV']
mean_val = np.mean(data)
std_val = np.std(data)
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(1+GHSV)')
plt.ylabel('Count')
plt.ylim(0,2500)
plt.title('Histogram of GHSV after Processing')

plt.tight_layout()
plt.show()
print(f"{mean_val:.4f},{std_val:.4f}")
# Out:
# 1.5234,0.8357

# %%
import matplotlib.pyplot as plt
data = react_df['Time on stream']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('min')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.xlim(0,9000)
plt.title('Histogram of Time on stream before Processing')

plt.tight_layout()
plt.show()
# Out:
# 281.4734,495.5217

# %%
react_df['Time on stream'] = np.log1p(react_df['Time on stream'])

# %%
import matplotlib.pyplot as plt
data = react_df['Time on stream']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(1+TOS)')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Time on stream After Processing')

plt.tight_layout()
plt.show()
# Out:
# 4.8620,1.2980

# %%
import numpy as np
for col in ['CO2 GHSV','CH4 GHSV']:
    react_df[f'{col}']= np.log1p(react_df[col])

# %%
pre_re_df = pd.concat([pre_df,react_df],axis=1)
pre_re_df = pre_re_df.drop(columns=['GHSV'])
pre_re_temp_df = pre_re_df.copy()

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Reaction T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('℃')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Reaction T before Processing')

plt.tight_layout()
plt.show()
# Out:
# 694.4690,87.3843

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Reduction T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('℃')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Reduction T before Processing')

plt.tight_layout()
plt.show()
# Out:
# 635.7933,159.4841

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Calcination T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('℃')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Calcination T before Processing')

plt.tight_layout()
plt.show()
# Out:
# 593.3615,136.5463

# %%
pre_re_temp_df['Reduction T'] = 1/(pre_re_temp_df['Reduction T']+273.15)
pre_re_temp_df['Reaction T'] = 1/(pre_re_temp_df['Reaction T']+273.15)
pre_re_temp_df['Calcination T'] = 1/(pre_re_temp_df['Calcination T']+273.15)

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Calcination T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('1/K')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Calcination T after Processing')

plt.tight_layout()
plt.show()
# Out:
# 0.0012,0.0002

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Reduction T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('1/K')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Reduction T after Processing')

plt.tight_layout()
plt.show()
# Out:
# 0.0012,0.0005

# %%
import matplotlib.pyplot as plt
data = pre_re_temp_df['Reaction T']
mean_val = np.mean(data)
std_val = np.std(data)
print(f"{mean_val:.4f},{std_val:.4f}")
plt.figure(figsize=(6,4))
plt.hist(
    data,
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('1/K')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Reaction T after Processing')

plt.tight_layout()
plt.show()
# Out:
# 0.0010,0.0001

# %%
import  numpy as np
np.save('./data/pre_re_temp.npy',pre_re_df)
np.save('./data/pre_re_change_temp.npy',pre_re_temp_df)

# %%
eps = 1e-100
pre_re_temp_df['Reaction_Constant'] = np.log(
    np.maximum(pre_re_temp_df['Reaction_Constant'], eps)
)

# %%
pre_re_temp_df['Reaction_Constant'].value_counts()
# Out:
# Reaction_Constant
#  3.185214      63
# -230.258509    54
#  1.739164      43
#  3.665809      31
#  2.313816      29
#                ..
# -2.085124       1
#  0.419369       1
#  0.385853       1
#  0.221155       1
#  0.156107       1
# Name: count, Length: 2038, dtype: int64

# %%
pre_re_df
# Out:
#       Calcination T  Calcination time  Reduction T  Reduction time  \
# 0               700               5.0          800             2.0
# 1               700               5.0          800             2.0
# 2               700               5.0          800             2.0
# 3               700               5.0          800             2.0
# 4               700               5.0          800             2.0
# ...             ...               ...          ...             ...
# 5903            300               6.0         1000            24.0
# 5904            300               6.0         1000            24.0
# 5905            300               6.0         1000            24.0
# 5906            300               6.0         1000            24.0
# 5907            300               6.0         1000            24.0
#
#       Reduction H2  Reaction T  CO2/CH4  CH4 GHSV  CO2 GHSV  Time on stream  \
# 0            33.33         600      0.0  1.098612  1.098612        4.110874
# 1            33.33         600      0.0  1.098612  1.098612        4.110874
# 2            33.33         600      0.0  1.098612  1.098612        4.110874
# 3            33.33         600      0.0  1.098612  1.098612        4.110874
# 4            33.33         600      0.0  1.098612  1.098612        4.110874
# ...            ...         ...      ...       ...       ...             ...
# 5903         40.00         700      0.0  0.117783  0.117783        4.795791
# 5904         40.00         750      0.0  0.117783  0.117783        4.795791
# 5905         40.00         800      0.0  0.117783  0.117783        4.795791
# 5906         40.00         850      0.0  0.117783  0.117783        4.795791
# 5907         40.00         900      0.0  0.117783  0.117783        4.795791
#
#       CH4 Conversion  Reaction_Constant
# 0                 21           1.045779
# 1                 39           2.394371
# 2                 45           2.982696
# 3                 48           3.311412
# 4                 44           2.878548
# ...              ...                ...
# 5903              81           1.043048
# 5904              90           1.501939
# 5905              95           2.009299
# 5906              97           2.387418
# 5907              98           2.689017
#
# [5908 rows x 12 columns]

# %%
pre_re_temp_df1 = pre_re_temp_df.drop(columns=['Reaction_Constant'])
np.save('./data/pre_re_change_temp_no_react_const.npy',pre_re_temp_df1)
np.save('./data/pre_re_change_temp_logconst.npy',pre_re_temp_df)
