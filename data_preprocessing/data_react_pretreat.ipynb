# %%
import pandas as pd
df =pd.read_csv('211210-DRM-total.csv')

# %%
pre_df = df.iloc[:,71:76]

# %%
react_df= df.iloc[:,76:]

# %%
react_df['CO2/CH4'] = df.loc[:,'Reaction CO2']/ df.loc[:,'Reaction CH4']

# %%
react_df['CH4 GHSV'] = react_df.loc[:,'Reaction CH4']*react_df.loc[:,'GHSV']/100
react_df['CO2 GHSV'] = react_df.loc[:,'Reaction CO2']*react_df.loc[:,'GHSV']/100
react_df['Space Time'] = 1/react_df.loc[:,'GHSV']

# %%
import numpy as np

react_df['Reaction_Constant'] = -np.log(1 - react_df['CH4 Conversion']/100) * react_df['GHSV']

# %%
react_df = react_df.loc[:,['Reaction T','CO2/CH4','CH4 GHSV','CO2 GHSV','GHSV','Time on stream','CH4 Conversion','Reaction_Constant']]

# %%
react_df.head()
# Out:
#    Reaction T  CO2/CH4  CH4 GHSV  CO2 GHSV  GHSV  Time on stream  \
# 0         600      1.0       2.0       2.0   4.0              60
# 1         600      1.0       2.0       2.0   4.0              60
# 2         600      1.0       2.0       2.0   4.0              60
# 3         600      1.0       2.0       2.0   4.0              60
# 4         600      1.0       2.0       2.0   4.0              60
#
#    CH4 Conversion  Reaction_Constant
# 0              21           0.942889
# 1              39           1.977185
# 2              45           2.391348
# 3              48           2.615706
# 4              44           2.319274

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['CO2/CH4'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('CO2/CH4 ratio')
plt.ylabel('Count')
plt.title('Histogram of CO2/CH4 before Processing')

plt.tight_layout()
plt.show()

# %%
import numpy as np
react_df['CO2/CH4']= np.log(react_df['CO2/CH4'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['CO2/CH4'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(CO2/CH4 ratio)')
plt.ylabel('Count')
plt.title('Histogram of CO2/CH4 after Processing')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['GHSV'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('GHSV')
plt.ylabel('Count')
plt.ylim(0,2500)
plt.title('Histogram of GHSV before Processing')

plt.tight_layout()
plt.show()

# %%
react_df['GHSV'] = np.log1p(react_df['GHSV'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['GHSV'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(1+GHSV)')
plt.ylabel('Count')
plt.ylim(0,2500)
plt.title('Histogram of GHSV after Processing')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['Time on stream'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('min')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Time on stream before Processing')

plt.tight_layout()
plt.show()

# %%
react_df['Time on stream'] = np.log1p(react_df['Time on stream'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(
    react_df['Time on stream'],
    bins=40,
    edgecolor='black',
    alpha=0.8
)

plt.xlabel('log(1+TOS)')
plt.ylabel('Count')
plt.ylim(0,3700)
plt.title('Histogram of Time on stream After Processing')

plt.tight_layout()
plt.show()

# %%
import numpy as np
for col in ['CO2 GHSV','CH4 GHSV']:
    react_df[f'{col}']= np.log1p(react_df[col])

# %%
pre_re_df = pd.concat([pre_df,react_df],axis=1)
pre_re_without_df = pre_re_df.drop(columns=['Reaction_Constant'])

# %%
import  numpy as np
np.save('./data/pre_re_fin_1.npy',pre_re_df)
np.save('./data/pre_re_without_reac_1.npy',pre_re_without_df)

# %% [markdown]
# ## 역변환

# %%
for col in ['Time on stream','CO2 GHSV','CH4 GHSV','GHSV']:
    react_df[col] = np.expm1(react_df[col])
react_df['CO2/CH4'] = np.exp(react_df['CO2/CH4'])

# %%
pre_re_df
# Out:
#       Calcination T  Calcination time  Reduction T  Reduction time  \
# 0               700               5.0          800             2.0
# 1               700               5.0          800             2.0
# 2               700               5.0          800             2.0
# 3               700               5.0          800             2.0
# 4               700               5.0          800             2.0
# ...             ...               ...          ...             ...
# 5903            300               6.0         1000            24.0
# 5904            300               6.0         1000            24.0
# 5905            300               6.0         1000            24.0
# 5906            300               6.0         1000            24.0
# 5907            300               6.0         1000            24.0
#
#       Reduction H2  Reaction T  CO2/CH4  CH4 GHSV  CO2 GHSV      GHSV  \
# 0            33.33         600      0.0  1.098612  1.098612  1.609438
# 1            33.33         600      0.0  1.098612  1.098612  1.609438
# 2            33.33         600      0.0  1.098612  1.098612  1.609438
# 3            33.33         600      0.0  1.098612  1.098612  1.609438
# 4            33.33         600      0.0  1.098612  1.098612  1.609438
# ...            ...         ...      ...       ...       ...       ...
# 5903         40.00         700      0.0  0.117783  0.117783  0.405465
# 5904         40.00         750      0.0  0.117783  0.117783  0.405465
# 5905         40.00         800      0.0  0.117783  0.117783  0.405465
# 5906         40.00         850      0.0  0.117783  0.117783  0.405465
# 5907         40.00         900      0.0  0.117783  0.117783  0.405465
#
#       Time on stream  CH4 Conversion  Reaction_Constant
# 0           4.110874              21           0.942889
# 1           4.110874              39           1.977185
# 2           4.110874              45           2.391348
# 3           4.110874              48           2.615706
# 4           4.110874              44           2.319274
# ...              ...             ...                ...
# 5903        4.795791              81           0.830366
# 5904        4.795791              90           1.151293
# 5905        4.795791              95           1.497866
# 5906        4.795791              97           1.753279
# 5907        4.795791              98           1.956012
#
# [5908 rows x 13 columns]
